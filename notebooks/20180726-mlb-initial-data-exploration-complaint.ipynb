# %% [markdown]
# ### INITIAL DATA EXPLORATION: FY 15 Conflict

# %%
import pandas as pd
import numpy as np

complaint_15 = pd.read_csv('../data/01_raw/fy_15_complaint.csv', skiprows=2)

# %%
complaint_15.head()
# Out:
#      Sample      Prod           DateSampled             Grade  DateTested  \
# 0  61915199  Gasoline  3/3/2015 12:00:00 AM  Premium Unleaded         NaN
# 1  61915199  Gasoline  3/3/2015 12:00:00 AM  Premium Unleaded         NaN
# 2  61915199  Gasoline  3/3/2015 12:00:00 AM  Premium Unleaded         NaN
# 3  61915199  Gasoline  3/3/2015 12:00:00 AM  Premium Unleaded         NaN
# 4  61915199  Gasoline  3/3/2015 12:00:00 AM  Premium Unleaded         NaN
#
#     HSID         Supplier  Gallons   FacilityName  \
# 0  17247  Tri-star Energy     2798  Hwy 100 Shell
# 1  17247  Tri-star Energy     2798  Hwy 100 Shell
# 2  17247  Tri-star Energy     2798  Hwy 100 Shell
# 3  17247  Tri-star Energy     2798  Hwy 100 Shell
# 4  17247  Tri-star Energy     2798  Hwy 100 Shell
#
#                                 SiteAddress              Test   Units Method  \
# 0  8456 Highway 100 \r\nnashville, Tn 37221   Antiknock Index          R+M/2
# ...
