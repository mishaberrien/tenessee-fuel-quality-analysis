# %% [markdown]
# ### Data Concatination & Data subset to gasoline & diesel

# %% [markdown]
# ##### In this notebook I combine all documents result & compliant documents into two datasets

# %%
# Import Libraries
import glob
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Read in all data files (5 per data file type) and concatenated

# %%
complaint = pd.concat([pd.read_csv(f, skiprows = 2) for f in glob.glob('../../data/01_raw/fy_*_complaint.csv')])
routine = pd.concat([pd.read_csv(f, skiprows = 2) for f in glob.glob('../../data/01_raw/fy_*_routine.csv')])
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (0,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
routine_gs = routine.loc[(routine['Prod'] == 'Gasoline') | (routine['Prod'] == 'Diesel')]

# %%
routine_gs.loc[(
    routine_gs['Compliance']=='Y') | (routine_gs['Compliance']=='N')].Test.value_counts().to_frame().reset_index()
# Out:
#                           index   Test
# 0              Distillation 90%  29545
# 1                   Workmanship  26572
# 2           Motor Octane Number  20675
# 3          Distillation Residue  20659
# 4             Distillation E.P.  20632
# 5            Driveability Index  20613
# 6              Distillation 10%  20537
# 7              Distillation 50%  20505
# 8                Vapor Pressure  20325
# 9            Vapor-Liquid Ratio  19911
# 10              Antiknock Index  19325
# 11             Phase Separation  17703
# 12                      Ethanol  12843
# 13                 Cetane Index   9107
# 14                       Sulfur   9103
# 15             Water & Sediment   9088
# 16            Biodiesel Content   8774
# 17                  Flash Point   8497
# 18                    Lubricity    595
# 19                 Total Oxygen    348
# 20    Enter a Product and Grade    155
# 21                  Cloud Point    130
# 22                         LTFT     52
# 23                  Acid Number     48
# 24          Oxidation Stability     48
# 25             Distillation 60%     44
# 26             Distillation 80%     30
# 27              Distillation 5%     19
# 28            Distillation Loss     12
# 29         Water - KF Titration     12
# 30             Distillation 70%     11
# 31             Distillation 95%      8
# 32       Research Octane Number      8
# 33             Relative Density      5
# 34             Distillation 20%      4
# 35  Particle Count - ISO Code 3      3
# 36                 KF Titration      2
# 37                     Methanol      2
# 38             Distillation 40%      2
# 39             Distillation IBP      2
# 40                  Haze Rating      1
# 41                        Water      1
# 42          Water, KF Titration      1
# 43                  API Gravity      1
# 44        Distillation Recovery      1

# %% [markdown]
# ##### Save concatenated files to Intermediate folder

# %%
routine.to_csv('../../data/02_intermediate/routine_inter.csv', index=False)
complaint.to_csv('../../data/02_intermediate/complaint_inter.csv', index=False)
